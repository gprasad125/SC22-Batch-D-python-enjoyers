# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %%
penguins_df = pd.read_csv("https://raw.githubusercontent.com/mcnakhaee/palmerpenguins/master/palmerpenguins/data/penguins-raw.csv")
penguins_df.head(10)
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 5   PAL0708              6  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 6   PAL0708              7  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 7   PAL0708              8  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 8   PAL0708              9  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 9   PAL0708             10  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion    Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  2007-11-11
# ...

# %%
# Example 1: I want only Male Penguins
male_penguins = penguins_df[penguins_df["Sex"] == "MALE"]
male_penguins.reset_index(inplace = True, drop = True)
male_penguins.head()
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              6  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              8  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708             14  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708             15  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion    Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  2007-11-11
# 1  Torgersen  Adult, 1 Egg Stage          N3A2               Yes  2007-11-16
# 2  Torgersen  Adult, 1 Egg Stage          N4A2                No  2007-11-15
# 3  Torgersen  Adult, 1 Egg Stage          N7A2               Yes  2007-11-15
# 4  Torgersen  Adult, 1 Egg Stage          N8A1               Yes  2007-11-16
#
# ...

# %%
# Example 2: I want Male Penguins AND I want Culmen Depth > 20

penguins_df.loc[(penguins_df["Sex"] == "MALE") 
                | (penguins_df["Culmen Depth (mm)"] > 20) 
                & (penguins_df["Flipper Length (mm)"] > 195.0)]
# Out:
#     studyName  Sample Number                                    Species  \
# 14    PAL0708             15        Adelie Penguin (Pygoscelis adeliae)
# 17    PAL0708             18        Adelie Penguin (Pygoscelis adeliae)
# 35    PAL0708             36        Adelie Penguin (Pygoscelis adeliae)
# 117   PAL0910            118        Adelie Penguin (Pygoscelis adeliae)
# 137   PAL0910            138        Adelie Penguin (Pygoscelis adeliae)
# 307   PAL0809             32  Chinstrap penguin (Pygoscelis antarctica)
# 313   PAL0809             38  Chinstrap penguin (Pygoscelis antarctica)
#
#      Region     Island               Stage Individual ID Clutch Completion  \
# 14   Anvers  Torgersen  Adult, 1 Egg Stage          N8A1               Yes
# 17   Anvers  Torgersen  Adult, 1 Egg Stage          N9A2               Yes
# 35   Anvers      Dream  Adult, 1 Egg Stage         N23A2               Yes
# 117  Anvers  Torgersen  Adult, 1 Egg Stage         N63A2               Yes
# ...
